# %%
import pandas as pd

# %%
# Anime Cleaned

anime_df = pd.read_csv('main-dataset/anime_cleaned.csv')
print(anime_df.shape)
print(anime_df.columns)
# Out:
# (6668, 33)
# Index(['anime_id', 'title', 'title_english', 'title_japanese',
#        'title_synonyms', 'image_url', 'type', 'source', 'episodes', 'status',
#        'airing', 'aired_string', 'aired', 'duration', 'rating', 'score',
#        'scored_by', 'rank', 'popularity', 'members', 'favorites', 'background',
#        'premiered', 'broadcast', 'related', 'producer', 'licensor', 'studio',
#        'genre', 'opening_theme', 'ending_theme', 'duration_min',
#        'aired_from_year'],
#       dtype='str')

# %%
# Anime Lists Dataset

animelist_df = pd.read_csv('main-dataset/animelists_cleaned.csv')

print(animelist_df.shape)
print(animelist_df.columns)
# Out:
# (31284030, 11)
# Index(['username', 'anime_id', 'my_watched_episodes', 'my_start_date',
#        'my_finish_date', 'my_score', 'my_status', 'my_rewatching',
#        'my_rewatching_ep', 'my_last_updated', 'my_tags'],
#       dtype='str')

# %%
# Users Dataset

users_df = pd.read_csv('main-dataset/users_cleaned.csv')

print(users_df.shape)
print(users_df.columns)
# Out:
# (108711, 17)
# Index(['username', 'user_id', 'user_watching', 'user_completed', 'user_onhold',
#        'user_dropped', 'user_plantowatch', 'user_days_spent_watching',
#        'gender', 'location', 'birth_date', 'access_rank', 'join_date',
#        'last_online', 'stats_mean_score', 'stats_rewatched', 'stats_episodes'],
#       dtype='str')

# %%
print(anime_df.shape)
print(anime_df[['title', 'popularity']].sort_values('popularity').head(15))
# Out:
# (6668, 33)
#                                  title  popularity
# 3802                        Death Note           1
# 3897                Shingeki no Kyojin           2
# 3009                  Sword Art Online           3
# 1261  Fullmetal Alchemist: Brotherhood           4
# 4215                     One Punch Man           5
# 630                        Tokyo Ghoul           6
# 6523                      Angel Beats!           7
# 1475                       Steins;Gate           8
# 6579   Code Geass: Hangyaku no Lelouch           9
# 2199                            Naruto          10
# 3108                   No Game No Life          11
# 4379                  Mirai Nikki (TV)          12
# 19                           Toradora!          13
# 2625                    Ao no Exorcist          14
# 3022                          Noragami          15

# %%
print(animelist_df.shape)
# print(users_df[['title', 'popularity']].sort_values('popularity').head(15))
print(animelist_df.columns)
print(animelist_df[['username', 'my_score', 'my_status']].head(15))
# Out:
# (31284030, 11)
# Index(['username', 'anime_id', 'my_watched_episodes', 'my_start_date',
#        'my_finish_date', 'my_score', 'my_status', 'my_rewatching',
#        'my_rewatching_ep', 'my_last_updated', 'my_tags'],
#       dtype='str')
#     username  my_score  my_status
# 0   karthiga         9          1
# 1   karthiga         7          2
# 2   karthiga         7          2
# 3   karthiga         7          2
# 4   karthiga         7          2
# 5   karthiga         7          2
# 6   karthiga         6          2
# 7   karthiga         6          2
# 8   karthiga         8          2
# 9   karthiga        10          2
# 10  karthiga         7          2
# 11  karthiga         7          2
# 12  karthiga        10          2
# 13  karthiga         8          2
# 14  karthiga        10          1
